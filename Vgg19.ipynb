# %%
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                      shear_range=0.2, 
                                        zoom_range=0.2,
                                        horizontal_flip=True)
x_train = train_datagen.flow_from_directory(
        'dataset/train',
        target_size = (32,32),
        # color_mode="grayscale",
        batch_size=4,
        class_mode='binary'
        )
# Out:
# Found 60 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
x_test = test_datagen.flow_from_directory(
        'dataset/test',
        target_size=(32,32),
        batch_size=4,
        # color_mode="grayscale",
        class_mode='binary')
# Out:
# Found 60 images belonging to 2 classes.

# %%
vgg = tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1,
    classifier_activation="softmax",
)

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
x = tf.keras.layers.GlobalMaxPooling2D()(vgg.output)
prediction = tf.keras.layers.Dense(1, activation='sigmoid')(x)

# # create a model object
model = tf.keras.models.Model(inputs=vgg.input, outputs=prediction)

# # view the structure of the model
model.summary()

# # tell the model what cost and optimization method to use
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 20,024,897
# Trainable params: 513
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
history = model.fit(
  x_train,
  validation_data=x_test,
  epochs=35,
)
# Out:
# Epoch 1/35
# 15/15 [==============================] - 5s 236ms/step - loss: 0.7478 - accuracy: 0.3833 - val_loss: 0.7001 - val_accuracy: 0.4333
# Epoch 2/35
# 15/15 [==============================] - 2s 119ms/step - loss: 0.7149 - accuracy: 0.3000 - val_loss: 0.7027 - val_accuracy: 0.4000
# Epoch 3/35
# 15/15 [==============================] - 2s 113ms/step - loss: 0.7060 - accuracy: 0.3333 - val_loss: 0.7067 - val_accuracy: 0.3833
# Epoch 4/35
# 15/15 [==============================] - 2s 114ms/step - loss: 0.6944 - accuracy: 0.5500 - val_loss: 0.7074 - val_accuracy: 0.3167
# Epoch 5/35
# 15/15 [==============================] - 2s 116ms/step - loss: 0.6930 - accuracy: 0.5167 - val_loss: 0.7124 - val_accuracy: 0.3000
# Epoch 6/35
# 15/15 [==============================] - 3s 174ms/step - loss: 0.6898 - accuracy: 0.5500 - val_loss: 0.7136 - val_accuracy: 0.3667
# Epoch 7/35
# 15/15 [==============================] - 2s 129ms/step - loss: 0.6902 - accuracy: 0.4667 - val_loss: 0.7144 - val_accuracy: 0.3500
# Epoch 8/35
# 15/15 [==============================] - 2s 132ms/step - loss: 0.6811 - accuracy: 0.5167 - val_loss: 0.7164 - val_accuracy: 0.4167
# Epoch 9/35
# 15/15 [==============================] - 2s 167ms/step - loss: 0.6756 - accuracy: 0.5667 - val_loss: 0.7187 - val_accuracy: 0.3667
# Epoch 10/35
# 15/15 [==============================] - 3s 201ms/step - loss: 0.6750 - accuracy: 0.5833 - val_loss: 0.7212 - val_accuracy: 0.3500
# Epoch 11/35
# 15/15 [==============================] - 2s 132ms/step - loss: 0.6644 - accuracy: 0.5000 - val_loss: 0.7231 - val_accuracy: 0.4167
# Epoch 12/35
# 15/15 [==============================] - 3s 187ms/step - loss: 0.6586 - accuracy: 0.6167 - val_loss: 0.7283 - val_accuracy: 0.4167
# Epoch 13/35
# 15/15 [==============================] - 3s 174ms/step - loss: 0.6669 - accuracy: 0.5500 - val_loss: 0.7299 - val_accuracy: 0.4333
# Epoch 14/35
# 15/15 [==============================] - 3s 171ms/step - loss: 0.6618 - accuracy: 0.6333 - val_loss: 0.7335 - val_accuracy: 0.4333
# Epoch 15/35
# 15/15 [==============================] - 2s 150ms/step - loss: 0.6604 - accuracy: 0.6167 - val_loss: 0.7334 - val_accuracy: 0.3667
# Epoch 16/35
# 15/15 [==============================] - 3s 173ms/step - loss: 0.6493 - accuracy: 0.6500 - val_loss: 0.7365 - val_accuracy: 0.4500
# Epoch 17/35
# 15/15 [==============================] - 2s 141ms/step - loss: 0.6466 - accuracy: 0.6000 - val_loss: 0.7383 - val_accuracy: 0.4333
# Epoch 18/35
# 15/15 [==============================] - 2s 124ms/step - loss: 0.6400 - accuracy: 0.6667 - val_loss: 0.7418 - val_accuracy: 0.4333
# Epoch 19/35
# 15/15 [==============================] - 2s 124ms/step - loss: 0.6431 - accuracy: 0.6500 - val_loss: 0.7448 - val_accuracy: 0.4167
# Epoch 20/35
# 15/15 [==============================] - 2s 127ms/step - loss: 0.6316 - accuracy: 0.6500 - val_loss: 0.7531 - val_accuracy: 0.4000
# Epoch 21/35
# 15/15 [==============================] - 2s 128ms/step - loss: 0.6421 - accuracy: 0.6667 - val_loss: 0.7540 - val_accuracy: 0.4167
# Epoch 22/35
# 15/15 [==============================] - 2s 133ms/step - loss: 0.6249 - accuracy: 0.7000 - val_loss: 0.7528 - val_accuracy: 0.4500
# Epoch 23/35
# 15/15 [==============================] - 2s 123ms/step - loss: 0.6186 - accuracy: 0.6500 - val_loss: 0.7590 - val_accuracy: 0.4167
# Epoch 24/35
# 15/15 [==============================] - 2s 130ms/step - loss: 0.6511 - accuracy: 0.5667 - val_loss: 0.7567 - val_accuracy: 0.4667
# Epoch 25/35
# 15/15 [==============================] - 2s 130ms/step - loss: 0.6044 - accuracy: 0.6833 - val_loss: 0.7586 - val_accuracy: 0.4500
# Epoch 26/35
# 15/15 [==============================] - 2s 127ms/step - loss: 0.6482 - accuracy: 0.6167 - val_loss: 0.7673 - val_accuracy: 0.4167
# Epoch 27/35
# 15/15 [==============================] - 2s 130ms/step - loss: 0.6269 - accuracy: 0.6167 - val_loss: 0.7606 - val_accuracy: 0.4667
# Epoch 28/35
# 15/15 [==============================] - 2s 125ms/step - loss: 0.6191 - accuracy: 0.6167 - val_loss: 0.7619 - val_accuracy: 0.4333
# Epoch 29/35
# 15/15 [==============================] - 2s 129ms/step - loss: 0.6461 - accuracy: 0.6667 - val_loss: 0.7631 - val_accuracy: 0.4333
# Epoch 30/35
# 15/15 [==============================] - 2s 138ms/step - loss: 0.6339 - accuracy: 0.6500 - val_loss: 0.7638 - val_accuracy: 0.4167
# Epoch 31/35
# 15/15 [==============================] - 2s 148ms/step - loss: 0.6381 - accuracy: 0.6333 - val_loss: 0.7677 - val_accuracy: 0.4500
# Epoch 32/35
# 15/15 [==============================] - 2s 137ms/step - loss: 0.6219 - accuracy: 0.6833 - val_loss: 0.7583 - val_accuracy: 0.4333
# Epoch 33/35
# 15/15 [==============================] - 2s 131ms/step - loss: 0.6167 - accuracy: 0.6167 - val_loss: 0.7594 - val_accuracy: 0.4333
# Epoch 34/35
# 15/15 [==============================] - 2s 123ms/step - loss: 0.6230 - accuracy: 0.6833 - val_loss: 0.7590 - val_accuracy: 0.4333
# Epoch 35/35
# 15/15 [==============================] - 2s 124ms/step - loss: 0.6289 - accuracy: 0.6167 - val_loss: 0.7693 - val_accuracy: 0.4500

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,36)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,36)
plt.plot(epochs, loss_train, 'g', label='Accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Accuracy and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
